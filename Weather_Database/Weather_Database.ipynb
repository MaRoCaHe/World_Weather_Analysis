# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Import the requests library.
import requests
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 741

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather['weather'][0]['description']
    
        # Append the city information into city_data list.
        city_data.append({"City": city.title(), 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds, 
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})
        
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
    
# Indicate the Data Loading is complete.
print("----------------------------")
print("Data Retrieval Complete     ")
print("----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | butaritari
# Processing Record 2 of Set 1 | sydney
# Processing Record 3 of Set 1 | tiarei
# Processing Record 4 of Set 1 | saint-philippe
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | faanui
# Processing Record 7 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 8 of Set 1 | tommot
# Processing Record 9 of Set 1 | khatanga
# Processing Record 10 of Set 1 | puerto escondido
# Processing Record 11 of Set 1 | mar del plata
# Processing Record 12 of Set 1 | port alfred
# Processing Record 13 of Set 1 | pevek
# Processing Record 14 of Set 1 | mataura
# Processing Record 15 of Set 1 | albany
# Processing Record 16 of Set 1 | ribeira grande
# Processing Record 17 of Set 1 | kenai
# Processing Record 18 of Set 1 | ginda
# Processing Record 19 of Set 1 | busselton
# Processing Record 20 of Set 1 | kieta
# Processing Record 21 of Set 1 | nantucket
# Processing Record 22 of Set 1 | georgetown
# Processing Record 23 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 24 of Set 1 | qaanaaq
# Processing Record 25 of Set 1 | yellowknife
# Processing Record 26 of Set 1 | atuona
# Processing Record 27 of Set 1 | tamale
# Processing Record 28 of Set 1 | oriximina
# Processing Record 29 of Set 1 | homer
# Processing Record 30 of Set 1 | kandrian
# Processing Record 31 of Set 1 | torres
# Processing Record 32 of Set 1 | mont-dore
# Processing Record 33 of Set 1 | ushuaia
# Processing Record 34 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 35 of Set 1 | sitka
# Processing Record 36 of Set 1 | lebu
# Processing Record 37 of Set 1 | qandala
# Processing Record 38 of Set 1 | leningradskiy
# Processing Record 39 of Set 1 | wittmund
# Processing Record 40 of Set 1 | punta arenas
# Processing Record 41 of Set 1 | luderitz
# Processing Record 42 of Set 1 | minab
# Processing Record 43 of Set 1 | kodiak
# Processing Record 44 of Set 1 | irece
# Processing Record 45 of Set 1 | coihaique
# Processing Record 46 of Set 1 | lagoa
# Processing Record 47 of Set 1 | castro
# Processing Record 48 of Set 1 | cidreira
# Processing Record 49 of Set 1 | tuktoyaktuk
# Processing Record 50 of Set 1 | chara
# Processing Record 1 of Set 2 | vaini
# Processing Record 2 of Set 2 | bakchar
# Processing Record 3 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 4 of Set 2 | kuopio
# Processing Record 5 of Set 2 | magsaysay
# Processing Record 6 of Set 2 | karaul
# City not found. Skipping...
# Processing Record 7 of Set 2 | miandrivazo
# Processing Record 8 of Set 2 | casablanca
# Processing Record 9 of Set 2 | xinyu
# Processing Record 10 of Set 2 | barrow
# Processing Record 11 of Set 2 | hobart
# Processing Record 12 of Set 2 | shaoguan
# Processing Record 13 of Set 2 | mrirt
# City not found. Skipping...
# Processing Record 14 of Set 2 | eenhana
# Processing Record 15 of Set 2 | port elizabeth
# Processing Record 16 of Set 2 | new norfolk
# Processing Record 17 of Set 2 | bredasdorp
# Processing Record 18 of Set 2 | vanimo
# Processing Record 19 of Set 2 | saint-augustin
# Processing Record 20 of Set 2 | bumbuna
# Processing Record 21 of Set 2 | iqaluit
# Processing Record 22 of Set 2 | hilo
# Processing Record 23 of Set 2 | wattegama
# Processing Record 24 of Set 2 | rio grande
# Processing Record 25 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 26 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 27 of Set 2 | hermanus
# Processing Record 28 of Set 2 | victoria
# Processing Record 29 of Set 2 | zhanatas
# City not found. Skipping...
# Processing Record 30 of Set 2 | naruja
# Processing Record 31 of Set 2 | seoul
# Processing Record 32 of Set 2 | paamiut
# Processing Record 33 of Set 2 | saskylakh
# Processing Record 34 of Set 2 | karamay
# City not found. Skipping...
# Processing Record 35 of Set 2 | angol
# Processing Record 36 of Set 2 | bethel
# Processing Record 37 of Set 2 | bolobo
# Processing Record 38 of Set 2 | dikson
# Processing Record 39 of Set 2 | cap malheureux
# Processing Record 40 of Set 2 | rongcheng
# Processing Record 41 of Set 2 | lompoc
# Processing Record 42 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 43 of Set 2 | pontivy
# Processing Record 44 of Set 2 | cape town
# Processing Record 45 of Set 2 | hauterive
# Processing Record 46 of Set 2 | klaksvik
# Processing Record 47 of Set 2 | mahibadhoo
# Processing Record 48 of Set 2 | baiyin
# Processing Record 49 of Set 2 | arlit
# Processing Record 50 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 1 of Set 3 | pacific grove
# Processing Record 2 of Set 3 | thinadhoo
# Processing Record 3 of Set 3 | kismayo
# Processing Record 4 of Set 3 | katsuura
# Processing Record 5 of Set 3 | balikpapan
# Processing Record 6 of Set 3 | ngukurr
# City not found. Skipping...
# Processing Record 7 of Set 3 | ruatoria
# City not found. Skipping...
# Processing Record 8 of Set 3 | bretcu
# Processing Record 9 of Set 3 | belyy yar
# Processing Record 10 of Set 3 | yumen
# Processing Record 11 of Set 3 | rognan
# Processing Record 12 of Set 3 | ilulissat
# Processing Record 13 of Set 3 | kahului
# Processing Record 14 of Set 3 | avarua
# Processing Record 15 of Set 3 | puerto ayora
# Processing Record 16 of Set 3 | east london
# Processing Record 17 of Set 3 | shingu
# Processing Record 18 of Set 3 | shirokovskiy
# Processing Record 19 of Set 3 | adrar
# Processing Record 20 of Set 3 | dubrovnik
# Processing Record 21 of Set 3 | monbon
# Processing Record 22 of Set 3 | takhtamygda
# Processing Record 23 of Set 3 | wajid
# Processing Record 24 of Set 3 | awbari
# Processing Record 25 of Set 3 | portland
# Processing Record 26 of Set 3 | souillac
# Processing Record 27 of Set 3 | nome
# Processing Record 28 of Set 3 | kapaa
# Processing Record 29 of Set 3 | lavrentiya
# Processing Record 30 of Set 3 | challapata
# Processing Record 31 of Set 3 | novoshakhtinsk
# Processing Record 32 of Set 3 | padang
# Processing Record 33 of Set 3 | haines junction
# Processing Record 34 of Set 3 | lasa
# Processing Record 35 of Set 3 | kloulklubed
# Processing Record 36 of Set 3 | olafsvik
# Processing Record 37 of Set 3 | mahebourg
# Processing Record 38 of Set 3 | ratnagiri
# Processing Record 39 of Set 3 | hithadhoo
# Processing Record 40 of Set 3 | ojinaga
# Processing Record 41 of Set 3 | corvallis
# Processing Record 42 of Set 3 | dunbar
# Processing Record 43 of Set 3 | pisco
# Processing Record 44 of Set 3 | mulanje
# Processing Record 45 of Set 3 | goma
# Processing Record 46 of Set 3 | jamestown
# Processing Record 47 of Set 3 | tasiilaq
# Processing Record 48 of Set 3 | bandarbeyla
# Processing Record 49 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 50 of Set 3 | kavaratti
# Processing Record 1 of Set 4 | san cristobal
# Processing Record 2 of Set 4 | moerai
# Processing Record 3 of Set 4 | salalah
# Processing Record 4 of Set 4 | mount gambier
# Processing Record 5 of Set 4 | bengkulu
# Processing Record 6 of Set 4 | puerto del rosario
# Processing Record 7 of Set 4 | kyra
# Processing Record 8 of Set 4 | lodja
# Processing Record 9 of Set 4 | puerto baquerizo moreno
# Processing Record 10 of Set 4 | mitsamiouli
# Processing Record 11 of Set 4 | hofn
# Processing Record 12 of Set 4 | pedernales
# Processing Record 13 of Set 4 | zyryanovsk
# Processing Record 14 of Set 4 | warkworth
# Processing Record 15 of Set 4 | luanda
# Processing Record 16 of Set 4 | pudozh
# Processing Record 17 of Set 4 | yar-sale
# Processing Record 18 of Set 4 | ponta do sol
# Processing Record 19 of Set 4 | segezha
# Processing Record 20 of Set 4 | tuatapere
# Processing Record 21 of Set 4 | gizo
# Processing Record 22 of Set 4 | megion
# Processing Record 23 of Set 4 | lata
# Processing Record 24 of Set 4 | bargal
# City not found. Skipping...
# Processing Record 25 of Set 4 | lagos
# Processing Record 26 of Set 4 | carnarvon
# Processing Record 27 of Set 4 | eyl
# Processing Record 28 of Set 4 | balboa
# Processing Record 29 of Set 4 | gat
# Processing Record 30 of Set 4 | wellington
# Processing Record 31 of Set 4 | zambezi
# Processing Record 32 of Set 4 | isangel
# Processing Record 33 of Set 4 | burnie
# Processing Record 34 of Set 4 | pochutla
# Processing Record 35 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 36 of Set 4 | goderich
# Processing Record 37 of Set 4 | thompson
# Processing Record 38 of Set 4 | eilenburg
# Processing Record 39 of Set 4 | tehuacan
# Processing Record 40 of Set 4 | severo-kurilsk
# Processing Record 41 of Set 4 | marsh harbour
# Processing Record 42 of Set 4 | provideniya
# Processing Record 43 of Set 4 | conde
# Processing Record 44 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 45 of Set 4 | champerico
# Processing Record 46 of Set 4 | alofi
# Processing Record 47 of Set 4 | maarianhamina
# Processing Record 48 of Set 4 | geraldton
# Processing Record 49 of Set 4 | labuhan
# Processing Record 50 of Set 4 | west wendover
# Processing Record 1 of Set 5 | cobija
# Processing Record 2 of Set 5 | plettenberg bay
# Processing Record 3 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 4 of Set 5 | laguna
# Processing Record 5 of Set 5 | pangnirtung
# Processing Record 6 of Set 5 | waingapu
# Processing Record 7 of Set 5 | xining
# Processing Record 8 of Set 5 | yagodnoye
# Processing Record 9 of Set 5 | hasaki
# Processing Record 10 of Set 5 | dingle
# Processing Record 11 of Set 5 | wenling
# Processing Record 12 of Set 5 | yeppoon
# Processing Record 13 of Set 5 | mount isa
# Processing Record 14 of Set 5 | hervey bay
# Processing Record 15 of Set 5 | zhigansk
# Processing Record 16 of Set 5 | verkhoyansk
# Processing Record 17 of Set 5 | derzhavinsk
# Processing Record 18 of Set 5 | kizlyar
# Processing Record 19 of Set 5 | hurricane
# Processing Record 20 of Set 5 | raga
# Processing Record 21 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 22 of Set 5 | kendari
# Processing Record 23 of Set 5 | cherskiy
# Processing Record 24 of Set 5 | namibe
# Processing Record 25 of Set 5 | bluff
# Processing Record 26 of Set 5 | fortuna
# Processing Record 27 of Set 5 | malindi
# Processing Record 28 of Set 5 | roma
# Processing Record 29 of Set 5 | buala
# Processing Record 30 of Set 5 | khani
# Processing Record 31 of Set 5 | chuy
# Processing Record 32 of Set 5 | bambous virieux
# Processing Record 33 of Set 5 | cabo san lucas
# Processing Record 34 of Set 5 | malwan
# City not found. Skipping...
# Processing Record 35 of Set 5 | nchelenge
# Processing Record 36 of Set 5 | samarai
# Processing Record 37 of Set 5 | richards bay
# Processing Record 38 of Set 5 | nikolskoye
# Processing Record 39 of Set 5 | kutum
# Processing Record 40 of Set 5 | darhan
# Processing Record 41 of Set 5 | wanning
# Processing Record 42 of Set 5 | naftah
# City not found. Skipping...
# Processing Record 43 of Set 5 | narsaq
# Processing Record 44 of Set 5 | rudnogorsk
# Processing Record 45 of Set 5 | necochea
# Processing Record 46 of Set 5 | camopi
# Processing Record 47 of Set 5 | longyearbyen
# Processing Record 48 of Set 5 | upernavik
# Processing Record 49 of Set 5 | faya
# Processing Record 50 of Set 5 | trenggalek
# Processing Record 1 of Set 6 | wainwright
# Processing Record 2 of Set 6 | san patricio
# Processing Record 3 of Set 6 | kusk
# City not found. Skipping...
# Processing Record 4 of Set 6 | fairbanks
# Processing Record 5 of Set 6 | elmira
# Processing Record 6 of Set 6 | kiunga
# Processing Record 7 of Set 6 | holbeach
# Processing Record 8 of Set 6 | kibala
# Processing Record 9 of Set 6 | kashi
# Processing Record 10 of Set 6 | slupca
# Processing Record 11 of Set 6 | bud
# Processing Record 12 of Set 6 | itoman
# Processing Record 13 of Set 6 | sorland
# Processing Record 14 of Set 6 | christchurch
# Processing Record 15 of Set 6 | jakarta
# Processing Record 16 of Set 6 | bin qirdan
# Processing Record 17 of Set 6 | sao filipe
# Processing Record 18 of Set 6 | manacapuru
# Processing Record 19 of Set 6 | vuktyl
# Processing Record 20 of Set 6 | aguililla
# Processing Record 21 of Set 6 | karratha
# Processing Record 22 of Set 6 | solovetskiy
# City not found. Skipping...
# Processing Record 23 of Set 6 | abha
# Processing Record 24 of Set 6 | papetoai
# Processing Record 25 of Set 6 | otofuke
# Processing Record 26 of Set 6 | fernandina beach
# Processing Record 27 of Set 6 | margate
# Processing Record 28 of Set 6 | naenwa
# City not found. Skipping...
# Processing Record 29 of Set 6 | villazon
# Processing Record 30 of Set 6 | sorvag
# City not found. Skipping...
# Processing Record 31 of Set 6 | tiksi
# Processing Record 32 of Set 6 | talnakh
# Processing Record 33 of Set 6 | baykit
# Processing Record 34 of Set 6 | high rock
# Processing Record 35 of Set 6 | bialystok
# Processing Record 36 of Set 6 | san buenaventura
# Processing Record 37 of Set 6 | poum
# Processing Record 38 of Set 6 | hailar
# Processing Record 39 of Set 6 | lorengau
# Processing Record 40 of Set 6 | aksarka
# Processing Record 41 of Set 6 | barentu
# Processing Record 42 of Set 6 | chokurdakh
# Processing Record 43 of Set 6 | najran
# Processing Record 44 of Set 6 | ayorou
# Processing Record 45 of Set 6 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 46 of Set 6 | nalut
# Processing Record 47 of Set 6 | te anau
# Processing Record 48 of Set 6 | touros
# Processing Record 49 of Set 6 | hambantota
# Processing Record 50 of Set 6 | ambon
# Processing Record 1 of Set 7 | quatre cocos
# Processing Record 2 of Set 7 | jiuquan
# Processing Record 3 of Set 7 | abu dhabi
# Processing Record 4 of Set 7 | cabedelo
# Processing Record 5 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 6 of Set 7 | kaitangata
# Processing Record 7 of Set 7 | bonthe
# Processing Record 8 of Set 7 | arraial do cabo
# Processing Record 9 of Set 7 | katangli
# Processing Record 10 of Set 7 | kaffrine
# Processing Record 11 of Set 7 | tazmalt
# Processing Record 12 of Set 7 | yulara
# Processing Record 13 of Set 7 | hobyo
# Processing Record 14 of Set 7 | dimitrovgrad
# Processing Record 15 of Set 7 | port-gentil
# Processing Record 16 of Set 7 | gladstone
# Processing Record 17 of Set 7 | dayong
# Processing Record 18 of Set 7 | bathsheba
# Processing Record 19 of Set 7 | pinheiro
# Processing Record 20 of Set 7 | senekal
# Processing Record 21 of Set 7 | niort
# Processing Record 22 of Set 7 | buraydah
# Processing Record 23 of Set 7 | torbay
# Processing Record 24 of Set 7 | bilibino
# Processing Record 25 of Set 7 | saint anthony
# Processing Record 26 of Set 7 | saint george
# Processing Record 27 of Set 7 | zabinka
# City not found. Skipping...
# Processing Record 28 of Set 7 | srednekolymsk
# Processing Record 29 of Set 7 | kudahuvadhoo
# Processing Record 30 of Set 7 | rocha
# Processing Record 31 of Set 7 | port macquarie
# Processing Record 32 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 33 of Set 7 | esperance
# Processing Record 34 of Set 7 | katherine
# Processing Record 35 of Set 7 | romitan
# Processing Record 36 of Set 7 | tocopilla
# Processing Record 37 of Set 7 | nizwa
# Processing Record 38 of Set 7 | trairi
# Processing Record 39 of Set 7 | smithers
# Processing Record 40 of Set 7 | vestmannaeyjar
# Processing Record 41 of Set 7 | saldanha
# Processing Record 42 of Set 7 | aitape
# Processing Record 43 of Set 7 | kaeo
# Processing Record 44 of Set 7 | comodoro rivadavia
# Processing Record 45 of Set 7 | mandera
# Processing Record 46 of Set 7 | provins
# Processing Record 47 of Set 7 | rabo de peixe
# Processing Record 48 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 49 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 50 of Set 7 | ibra
# Processing Record 1 of Set 8 | xuddur
# Processing Record 2 of Set 8 | mehamn
# Processing Record 3 of Set 8 | nanortalik
# Processing Record 4 of Set 8 | santa isabel do rio negro
# Processing Record 5 of Set 8 | nam tha
# City not found. Skipping...
# Processing Record 6 of Set 8 | flin flon
# Processing Record 7 of Set 8 | huarmey
# Processing Record 8 of Set 8 | flinders
# Processing Record 9 of Set 8 | saint-pierre
# Processing Record 10 of Set 8 | panaba
# Processing Record 11 of Set 8 | susehri
# Processing Record 12 of Set 8 | sandnessjoen
# Processing Record 13 of Set 8 | zachepylivka
# Processing Record 14 of Set 8 | high prairie
# Processing Record 15 of Set 8 | la ronge
# Processing Record 16 of Set 8 | la reforma
# Processing Record 17 of Set 8 | tura
# Processing Record 18 of Set 8 | mardin
# Processing Record 19 of Set 8 | ketchikan
# Processing Record 20 of Set 8 | havre-saint-pierre
# Processing Record 21 of Set 8 | naze
# Processing Record 22 of Set 8 | quelimane
# Processing Record 23 of Set 8 | joura
# Processing Record 24 of Set 8 | maunabo
# Processing Record 25 of Set 8 | hihifo
# City not found. Skipping...
# Processing Record 26 of Set 8 | bouca
# Processing Record 27 of Set 8 | qianan
# Processing Record 28 of Set 8 | shakawe
# Processing Record 29 of Set 8 | tongliao
# Processing Record 30 of Set 8 | airai
# Processing Record 31 of Set 8 | singaraja
# Processing Record 32 of Set 8 | kegayli
# City not found. Skipping...
# Processing Record 33 of Set 8 | orcotuna
# Processing Record 34 of Set 8 | gubkinskiy
# Processing Record 35 of Set 8 | belmonte
# Processing Record 36 of Set 8 | zhongshu
# Processing Record 37 of Set 8 | karpathos
# Processing Record 38 of Set 8 | wuchi
# Processing Record 39 of Set 8 | kavieng
# Processing Record 40 of Set 8 | mount holly
# Processing Record 41 of Set 8 | alekseyevsk
# Processing Record 42 of Set 8 | le port
# Processing Record 43 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 44 of Set 8 | utkivka
# Processing Record 45 of Set 8 | havelock
# Processing Record 46 of Set 8 | powell river
# Processing Record 47 of Set 8 | suntar
# Processing Record 48 of Set 8 | san felipe
# Processing Record 49 of Set 8 | long branch
# Processing Record 50 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 1 of Set 9 | brajrajnagar
# City not found. Skipping...
# Processing Record 2 of Set 9 | kirakira
# Processing Record 3 of Set 9 | ust-omchug
# Processing Record 4 of Set 9 | shangzhi
# Processing Record 5 of Set 9 | keetmanshoop
# Processing Record 6 of Set 9 | rancho palos verdes
# Processing Record 7 of Set 9 | villa rica
# Processing Record 8 of Set 9 | celestun
# Processing Record 9 of Set 9 | sioux lookout
# Processing Record 10 of Set 9 | carutapera
# Processing Record 11 of Set 9 | vanderhoof
# Processing Record 12 of Set 9 | orbetello
# Processing Record 13 of Set 9 | fort dix
# Processing Record 14 of Set 9 | seddon
# Processing Record 15 of Set 9 | kalamakion
# City not found. Skipping...
# Processing Record 16 of Set 9 | mawlaik
# Processing Record 17 of Set 9 | skjervoy
# Processing Record 18 of Set 9 | nhulunbuy
# Processing Record 19 of Set 9 | coolum beach
# Processing Record 20 of Set 9 | tra vinh
# Processing Record 21 of Set 9 | north bend
# Processing Record 22 of Set 9 | port augusta
# Processing Record 23 of Set 9 | kamenka
# Processing Record 24 of Set 9 | vanavara
# Processing Record 25 of Set 9 | coahuayana
# Processing Record 26 of Set 9 | nambucca heads
# Processing Record 27 of Set 9 | imbituba
# Processing Record 28 of Set 9 | kulu
# Processing Record 29 of Set 9 | fuyang
# Processing Record 30 of Set 9 | san juan de uraba
# Processing Record 31 of Set 9 | bridlington
# Processing Record 32 of Set 9 | halalo
# City not found. Skipping...
# Processing Record 33 of Set 9 | marawi
# Processing Record 34 of Set 9 | ossora
# Processing Record 35 of Set 9 | guerrero negro
# Processing Record 36 of Set 9 | scarborough
# Processing Record 37 of Set 9 | codrington
# Processing Record 38 of Set 9 | mikun
# Processing Record 39 of Set 9 | port lincoln
# Processing Record 40 of Set 9 | korla
# Processing Record 41 of Set 9 | sibu
# Processing Record 42 of Set 9 | eldama ravine
# Processing Record 43 of Set 9 | warmbad
# Processing Record 44 of Set 9 | dongsheng
# Processing Record 45 of Set 9 | talavera de la reina
# Processing Record 46 of Set 9 | lazi
# Processing Record 47 of Set 9 | taburi
# City not found. Skipping...
# Processing Record 48 of Set 9 | mayen
# Processing Record 49 of Set 9 | umm durman
# City not found. Skipping...
# Processing Record 50 of Set 9 | grand gaube
# Processing Record 1 of Set 10 | oranjestad
# Processing Record 2 of Set 10 | agirish
# Processing Record 3 of Set 10 | qingan
# City not found. Skipping...
# Processing Record 4 of Set 10 | kelvington
# Processing Record 5 of Set 10 | kruisfontein
# Processing Record 6 of Set 10 | camacha
# Processing Record 7 of Set 10 | nibbar
# Processing Record 8 of Set 10 | govindgarh
# Processing Record 9 of Set 10 | eufaula
# Processing Record 10 of Set 10 | ipixuna
# Processing Record 11 of Set 10 | sobolevo
# Processing Record 12 of Set 10 | lewiston
# Processing Record 13 of Set 10 | santa maria
# Processing Record 14 of Set 10 | katobu
# Processing Record 15 of Set 10 | port moresby
# Processing Record 16 of Set 10 | ugoofaaru
# Processing Record 17 of Set 10 | barbar
# City not found. Skipping...
# Processing Record 18 of Set 10 | terney
# Processing Record 19 of Set 10 | kazalinsk
# City not found. Skipping...
# Processing Record 20 of Set 10 | saquarema
# Processing Record 21 of Set 10 | basco
# Processing Record 22 of Set 10 | sergeyevka
# Processing Record 23 of Set 10 | coquimbo
# Processing Record 24 of Set 10 | san francisco menendez
# Processing Record 25 of Set 10 | bokovskaya
# Processing Record 26 of Set 10 | sur
# Processing Record 27 of Set 10 | batagay-alyta
# Processing Record 28 of Set 10 | zhezkazgan
# Processing Record 29 of Set 10 | grande riviere du nord
# Processing Record 30 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 31 of Set 10 | mozelos
# Processing Record 32 of Set 10 | half moon bay
# Processing Record 33 of Set 10 | blind river
# Processing Record 34 of Set 10 | vila franca do campo
# Processing Record 35 of Set 10 | casimiro castillo
# Processing Record 36 of Set 10 | broome
# Processing Record 37 of Set 10 | ampanihy
# Processing Record 38 of Set 10 | sao miguel do araguaia
# Processing Record 39 of Set 10 | mana
# Processing Record 40 of Set 10 | hamilton
# Processing Record 41 of Set 10 | marystown
# Processing Record 42 of Set 10 | ontario
# Processing Record 43 of Set 10 | moose factory
# Processing Record 44 of Set 10 | egvekinot
# Processing Record 45 of Set 10 | tunduru
# City not found. Skipping...
# Processing Record 46 of Set 10 | sinnamary
# Processing Record 47 of Set 10 | frumoasa
# Processing Record 48 of Set 10 | hearst
# Processing Record 49 of Set 10 | santa barbara
# Processing Record 50 of Set 10 | skibbereen
# Processing Record 1 of Set 11 | sao domingos do maranhao
# Processing Record 2 of Set 11 | beisfjord
# Processing Record 3 of Set 11 | meadow lake
# Processing Record 4 of Set 11 | raton
# Processing Record 5 of Set 11 | owando
# Processing Record 6 of Set 11 | aykhal
# Processing Record 7 of Set 11 | sachin
# Processing Record 8 of Set 11 | orlik
# Processing Record 9 of Set 11 | a
# City not found. Skipping...
# Processing Record 10 of Set 11 | lincoln
# Processing Record 11 of Set 11 | bolshiye uki
# City not found. Skipping...
# Processing Record 12 of Set 11 | alta floresta
# Processing Record 13 of Set 11 | texarkana
# Processing Record 14 of Set 11 | waipawa
# Processing Record 15 of Set 11 | mayo
# Processing Record 16 of Set 11 | norman wells
# Processing Record 17 of Set 11 | brokopondo
# Processing Record 18 of Set 11 | port hardy
# Processing Record 19 of Set 11 | sorong
# Processing Record 20 of Set 11 | maine-soroa
# Processing Record 21 of Set 11 | yirol
# City not found. Skipping...
# Processing Record 22 of Set 11 | tautira
# Processing Record 23 of Set 11 | college
# Processing Record 24 of Set 11 | huanan
# Processing Record 25 of Set 11 | clemencia
# Processing Record 26 of Set 11 | neuquen
# Processing Record 27 of Set 11 | mackenzie
# Processing Record 28 of Set 11 | san luis
# Processing Record 29 of Set 11 | muhos
# Processing Record 30 of Set 11 | northam
# Processing Record 31 of Set 11 | nouakchott
# Processing Record 32 of Set 11 | new baltimore
# Processing Record 33 of Set 11 | maniitsoq
# Processing Record 34 of Set 11 | palmer
# Processing Record 35 of Set 11 | andrews
# Processing Record 36 of Set 11 | koumac
# Processing Record 37 of Set 11 | khorixas
# Processing Record 38 of Set 11 | voh
# Processing Record 39 of Set 11 | arcata
# Processing Record 40 of Set 11 | nedjo
# Processing Record 41 of Set 11 | nosy varika
# Processing Record 42 of Set 11 | severnoye
# Processing Record 43 of Set 11 | asfi
# Processing Record 44 of Set 11 | pierre
# Processing Record 45 of Set 11 | lovozero
# Processing Record 46 of Set 11 | ancud
# Processing Record 47 of Set 11 | rolim de moura
# City not found. Skipping...
# Processing Record 48 of Set 11 | moyamba
# Processing Record 49 of Set 11 | weatherford
# Processing Record 50 of Set 11 | parana
# Processing Record 1 of Set 12 | bitung
# Processing Record 2 of Set 12 | paranaiba
# Processing Record 3 of Set 12 | vao
# Processing Record 4 of Set 12 | bandipur
# Processing Record 5 of Set 12 | poya
# Processing Record 6 of Set 12 | meulaboh
# Processing Record 7 of Set 12 | nikolayevka
# Processing Record 8 of Set 12 | anadyr
# Processing Record 9 of Set 12 | safaga
# Processing Record 10 of Set 12 | aklavik
# Processing Record 11 of Set 12 | lahat
# Processing Record 12 of Set 12 | erenhot
# Processing Record 13 of Set 12 | bulgan
# Processing Record 14 of Set 12 | ostrovnoy
# Processing Record 15 of Set 12 | dusetos
# Processing Record 16 of Set 12 | tawang
# Processing Record 17 of Set 12 | brae
# Processing Record 18 of Set 12 | covilha
# Processing Record 19 of Set 12 | mogadishu
# Processing Record 20 of Set 12 | yarmouth
# Processing Record 21 of Set 12 | vestmanna
# Processing Record 22 of Set 12 | bindura
# Processing Record 23 of Set 12 | norsup
# Processing Record 24 of Set 12 | talcahuano
# Processing Record 25 of Set 12 | ban nahin
# Processing Record 26 of Set 12 | batagay
# Processing Record 27 of Set 12 | simbahan
# Processing Record 28 of Set 12 | praia da vitoria
# Processing Record 29 of Set 12 | butembo
# Processing Record 30 of Set 12 | ouesso
# Processing Record 31 of Set 12 | bilma
# Processing Record 32 of Set 12 | panguipulli
# Processing Record 33 of Set 12 | sao raimundo nonato
# Processing Record 34 of Set 12 | paciran
# Processing Record 35 of Set 12 | chipinge
# Processing Record 36 of Set 12 | simao
# Processing Record 37 of Set 12 | vologda
# Processing Record 38 of Set 12 | big bend
# Processing Record 39 of Set 12 | bubaque
# Processing Record 40 of Set 12 | cairns
# Processing Record 41 of Set 12 | braganca
# Processing Record 42 of Set 12 | manhattan beach
# Processing Record 43 of Set 12 | manokwari
# Processing Record 44 of Set 12 | port blair
# Processing Record 45 of Set 12 | chiredzi
# Processing Record 46 of Set 12 | cabra
# Processing Record 47 of Set 12 | sume
# Processing Record 48 of Set 12 | banda aceh
# Processing Record 49 of Set 12 | inhambane
# Processing Record 50 of Set 12 | trindade
# Processing Record 1 of Set 13 | jiddah
# City not found. Skipping...
# Processing Record 2 of Set 13 | burica
# City not found. Skipping...
# Processing Record 3 of Set 13 | dawson creek
# Processing Record 4 of Set 13 | presidencia roque saenz pena
# Processing Record 5 of Set 13 | antigonish
# Processing Record 6 of Set 13 | qaqortoq
# Processing Record 7 of Set 13 | danli
# Processing Record 8 of Set 13 | coari
# Processing Record 9 of Set 13 | mackay
# Processing Record 10 of Set 13 | krasnaya polyana
# Processing Record 11 of Set 13 | hermosillo
# Processing Record 12 of Set 13 | barroso
# Processing Record 13 of Set 13 | trinidad
# Processing Record 14 of Set 13 | bohodukhiv
# Processing Record 15 of Set 13 | el faiyum
# City not found. Skipping...
# Processing Record 16 of Set 13 | santa rosa
# Processing Record 17 of Set 13 | banikoara
# Processing Record 18 of Set 13 | vagur
# Processing Record 19 of Set 13 | beira
# Processing Record 20 of Set 13 | san quintin
# Processing Record 21 of Set 13 | angra
# City not found. Skipping...
# Processing Record 22 of Set 13 | jurmala
# Processing Record 23 of Set 13 | huilong
# Processing Record 24 of Set 13 | teya
# Processing Record 25 of Set 13 | severnyy
# Processing Record 26 of Set 13 | beringovskiy
# Processing Record 27 of Set 13 | huanren
# Processing Record 28 of Set 13 | deputatskiy
# Processing Record 29 of Set 13 | mandiana
# Processing Record 30 of Set 13 | lensk
# Processing Record 31 of Set 13 | muzquiz
# City not found. Skipping...
# Processing Record 32 of Set 13 | biak
# Processing Record 33 of Set 13 | gao
# Processing Record 34 of Set 13 | minggang
# Processing Record 35 of Set 13 | ranong
# Processing Record 36 of Set 13 | avera
# Processing Record 37 of Set 13 | safranbolu
# Processing Record 38 of Set 13 | durango
# Processing Record 39 of Set 13 | ukiah
# Processing Record 40 of Set 13 | rungata
# City not found. Skipping...
# Processing Record 41 of Set 13 | marang
# Processing Record 42 of Set 13 | dunedin
# Processing Record 43 of Set 13 | barranca
# Processing Record 44 of Set 13 | araripina
# Processing Record 45 of Set 13 | longhua
# Processing Record 46 of Set 13 | ngunguru
# Processing Record 47 of Set 13 | manta
# Processing Record 48 of Set 13 | leninsk-kuznetskiy
# Processing Record 49 of Set 13 | amazar
# Processing Record 50 of Set 13 | hays
# Processing Record 1 of Set 14 | udachnyy
# Processing Record 2 of Set 14 | vorobyevka
# Processing Record 3 of Set 14 | francisco sa
# Processing Record 4 of Set 14 | nelson bay
# Processing Record 5 of Set 14 | the valley
# Processing Record 6 of Set 14 | havoysund
# Processing Record 7 of Set 14 | lipari
# Processing Record 8 of Set 14 | sedelnikovo
# City not found. Skipping...
# Processing Record 9 of Set 14 | tsurib
# Processing Record 10 of Set 14 | buin
# Processing Record 11 of Set 14 | general roca
# Processing Record 12 of Set 14 | anton lizardo
# Processing Record 13 of Set 14 | pa sang
# Processing Record 14 of Set 14 | umm lajj
# Processing Record 15 of Set 14 | vila velha
# Processing Record 16 of Set 14 | bronnoysund
# Processing Record 17 of Set 14 | korolevo
# Processing Record 18 of Set 14 | tabuk
# Processing Record 19 of Set 14 | berlevag
# Processing Record 20 of Set 14 | west helena
# Processing Record 21 of Set 14 | camacupa
# Processing Record 22 of Set 14 | sondershausen
# Processing Record 23 of Set 14 | moindou
# Processing Record 24 of Set 14 | ahipara
# Processing Record 25 of Set 14 | rio de janeiro
# Processing Record 26 of Set 14 | manzil tamim
# City not found. Skipping...
# Processing Record 27 of Set 14 | taoudenni
# Processing Record 28 of Set 14 | itatiaia
# Processing Record 29 of Set 14 | yenagoa
# Processing Record 30 of Set 14 | alice springs
# Processing Record 31 of Set 14 | mandalgovi
# Processing Record 32 of Set 14 | batemans bay
# Processing Record 33 of Set 14 | whitehorse
# Processing Record 34 of Set 14 | muravlenko
# Processing Record 35 of Set 14 | grand-santi
# Processing Record 36 of Set 14 | mayumba
# Processing Record 37 of Set 14 | santa fe
# Processing Record 38 of Set 14 | amahai
# Processing Record 39 of Set 14 | togur
# Processing Record 40 of Set 14 | estelle
# Processing Record 41 of Set 14 | nicoya
# Processing Record 42 of Set 14 | griffith
# Processing Record 43 of Set 14 | garowe
# Processing Record 44 of Set 14 | fort saint james
# Processing Record 45 of Set 14 | thilogne
# City not found. Skipping...
# Processing Record 46 of Set 14 | cayenne
# Processing Record 47 of Set 14 | diffa
# Processing Record 48 of Set 14 | belaya gora
# Processing Record 49 of Set 14 | raudeberg
# Processing Record 50 of Set 14 | pangai
# Processing Record 1 of Set 15 | takoradi
# Processing Record 2 of Set 15 | villanueva
# Processing Record 3 of Set 15 | trofors
# Processing Record 4 of Set 15 | kapoeta
# Processing Record 5 of Set 15 | sanchor
# Processing Record 6 of Set 15 | koumra
# Processing Record 7 of Set 15 | baruun-urt
# Processing Record 8 of Set 15 | ondjiva
# Processing Record 9 of Set 15 | douazeci si trei august
# Processing Record 10 of Set 15 | miranorte
# City not found. Skipping...
# Processing Record 11 of Set 15 | rovinj
# Processing Record 12 of Set 15 | hurezani
# Processing Record 13 of Set 15 | anibongan
# Processing Record 14 of Set 15 | la rochelle
# Processing Record 15 of Set 15 | sylacauga
# Processing Record 16 of Set 15 | sedhiou
# Processing Record 17 of Set 15 | ustka
# Processing Record 18 of Set 15 | yangjiang
# Processing Record 19 of Set 15 | cockburn town
# Processing Record 20 of Set 15 | kelapa sawit
# Processing Record 21 of Set 15 | west bay
# Processing Record 22 of Set 15 | stolin
# Processing Record 23 of Set 15 | kochubey
# Processing Record 24 of Set 15 | anori
# Processing Record 25 of Set 15 | salinopolis
# Processing Record 26 of Set 15 | krasnoselkup
# Processing Record 27 of Set 15 | porto novo
# Processing Record 28 of Set 15 | oloron-sainte-marie
# Processing Record 29 of Set 15 | sabha
# Processing Record 30 of Set 15 | marienburg
# Processing Record 31 of Set 15 | solnechnyy
# Processing Record 32 of Set 15 | sistranda
# Processing Record 33 of Set 15 | khagrachari
# City not found. Skipping...
# Processing Record 34 of Set 15 | rawson
# Processing Record 35 of Set 15 | mangrol
# Processing Record 36 of Set 15 | borogontsy
# Processing Record 37 of Set 15 | vredendal
# Processing Record 38 of Set 15 | general pico
# Processing Record 39 of Set 15 | kayseri
# Processing Record 40 of Set 15 | ozgon
# City not found. Skipping...
# Processing Record 41 of Set 15 | hazorasp
# ----------------------------
# Data Retrieval Complete
# ----------------------------

# %%
len(city_data)
# Out:
# 678

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Butaritari   3.0707  172.7902     81.72        70          98
# 1            Sydney -33.8679  151.2073     61.48        57           0
# 2            Tiarei -17.5333 -149.3333     82.42        73          77
# 3    Saint-Philippe -21.3585   55.7679     67.59        85          50
# 4           Rikitea -23.1203 -134.9692     74.62        77         100
# 5            Faanui -16.4833 -151.7500     78.03        74          25
# 6            Tommot  58.9564  126.2925     66.38        91           3
# 7          Khatanga  71.9667  102.5000     75.61        57          99
# 8  Puerto Escondido  15.8500  -97.0667     86.41        68          95
# 9     Mar Del Plata -38.0023  -57.5575     47.12        69          15
#
#    Wind Speed Country Current Description
# 0        3.49      KI     overcast clouds
# 1        5.01      AU           clear sky
# 2       10.02      PF       broken clouds
# 3       14.20      RE          light rain
# 4       15.01      PF     overcast clouds
# 5        7.70      PF          light rain
# 6        2.01      RU           clear sky
# 7       15.93      RU     overcast clouds
# 8        4.97      MX     overcast clouds
# 9       11.01      AR          light rain

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 0        Butaritari      KI   3.0707  172.7902     81.72        70
# 1            Sydney      AU -33.8679  151.2073     61.48        57
# 2            Tiarei      PF -17.5333 -149.3333     82.42        73
# 3    Saint-Philippe      RE -21.3585   55.7679     67.59        85
# 4           Rikitea      PF -23.1203 -134.9692     74.62        77
# 5            Faanui      PF -16.4833 -151.7500     78.03        74
# 6            Tommot      RU  58.9564  126.2925     66.38        91
# 7          Khatanga      RU  71.9667  102.5000     75.61        57
# 8  Puerto Escondido      MX  15.8500  -97.0667     86.41        68
# 9     Mar Del Plata      AR -38.0023  -57.5575     47.12        69
#
#    Cloudiness  Wind Speed Current Description
# 0          98        3.49     overcast clouds
# 1           0        5.01           clear sky
# 2          77       10.02       broken clouds
# 3          50       14.20          light rain
# 4         100       15.01     overcast clouds
# 5          25        7.70          light rain
# 6           3        2.01           clear sky
# 7          99       15.93     overcast clouds
# 8          95        4.97     overcast clouds
# 9          15       11.01          light rain

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
